# %%
'''
import requests as req

def get_plausible_url(domain):
    yield 'https://www.{}'.format(domain)
    yield 'https://{}'.format(domain)
    yield 'http://{}'.format(domain)
    yield 'http://www.{}'.format(domain)

with open('top10000.txt') as alexa_list:
    index = 1
    for website in alexa_list:
        website = website.strip()

        for url in get_plausible_url(website):
            robotstxt_url = '{}/robots.txt'.format(url)
            print('[{}] downloading {}'.format(index, robotstxt_url))
            try:
                response = req.get(robotstxt_url, timeout=5)
            except:
                print('[{}] download failed for {}'.format(index, robotstxt_url))
                continue
            else:
                with open('robotstxt_new/{}'.format(website), 'wb') as f:
                    f.write(response.content)
                print('[{}] written {}'.format(index, robotstxt_url))
                break

        index += 1
'''
# Out:
# "\nimport requests as req\n\ndef get_plausible_url(domain):\n    yield 'https://www.{}'.format(domain)\n    yield 'https://{}'.format(domain)\n    yield 'http://{}'.format(domain)\n    yield 'http://www.{}'.format(domain)\n\nwith open('top10000.txt') as alexa_list:\n    index = 1\n    for website in alexa_list:\n        website = website.strip()\n\n        for url in get_plausible_url(website):\n            robotstxt_url = '{}/robots.txt'.format(url)\n            print('[{}] downloading {}'.format(index, robotstxt_url))\n            try:\n                response = req.get(robotstxt_url, timeout=5)\n            except:\n                print('[{}] download failed for {}'.format(index, robotstxt_url))\n                continue\n            else:\n                with open('robotstxt_new/{}'.format(website), 'wb') as f:\n                    f.write(response.content)\n                print('[{}] written {}'.format(index, robotstxt_url))\n                break\n\n        index += 1\n"

# %%
from os import listdir
from os.path import isfile, join
import pandas as pd
from termcolor import colored
import sys

PATH_TO_DIR = './robotstxt'
files = (f for f in listdir(PATH_TO_DIR) if isfile(join(PATH_TO_DIR, f)))

user_agents = set()
directive_count = {}
count_per_website = {}

def parse_robotstxt(content):
    directives_on_this_website = set()
    
    lines = content.split('\n')
    for line in lines:
        hash_pos = line.find('#')
        if hash_pos != -1:
            line = line[0: hash_pos].strip()

        line = line.strip()
        if not line:
            continue

        line = line.strip()
        field, value = line.split(':', 1)
        field = field.strip().lower()
        value = value.strip()

        if field not in directive_count:
            directive_count[field] = 0
        directive_count[field] += 1
        
        if field not in directives_on_this_website:
            directives_on_this_website.add(field)
            if field not in count_per_website:
                count_per_website[field] = 0
            count_per_website[field] += 1
        
        if field == 'user-agent':
            user_agents.add(value)

        
website_count = 0
for filename in files:
    with open('robotstxt/{}'.format(filename), 'r') as f:
        website_count += 1
        try:
            content = f.read()
            parse_robotstxt(content)
        except:
            print("error occured while parsing {}".format(filename), file=sys.stderr)
print("No of websites : {}".format(website_count))
# Out:
# No of websites : 965
# error occured while parsing beeg.com
# error occured while parsing drive2.ru
# error occured while parsing media.tumblr.com
# error occured while parsing epochtimes.com
# error occured while parsing codepen.io
# error occured while parsing istockphoto.com
# error occured while parsing amazonaws.com
# error occured while parsing myway.com
# error occured while parsing thewhizmarketing.com
# error occured while parsing bancodevenezuela.com
# error occured while parsing billdesk.com
# error occured while parsing ozon.ru
# error occured while parsing banesconline.com
# error occured while parsing leboncoin.fr
# error occured while parsing sportzbonanza.com
# error occured while parsing tabelog.com
# error occured while parsing ltn.com.tw
# error occured while parsing taleo.net
# error occured while parsing bet9ja.com
# error occured while parsing aparat.com
# error occured while parsing yy.com
# error occured while parsing alipay.com
# error occured while parsing jqw.com
# error occured while parsing jd.hk
# error occured while parsing t.me
# error occured while parsing varzesh3.com
# error occured while parsing wiktionary.org
# error occured while parsing farsnews.com
# error occured while parsing citi.com
# error occured while parsing 126.com
# error occured while parsing nga.cn
# error occured while parsing justdial.com
# error occured while parsing lordfilms.tv
# error occured while parsing kissanime.ru
# error occured while parsing onlinesbi.com
# error occured while parsing telegram.org
# error occured while parsing xinhuanet.com
# error occured while parsing huffpost.com
# error occured while parsing jianshu.com
# error occured while parsing kissasian.sh
# error occured while parsing incometaxindiaefiling.gov.in
# error occured while parsing qualtrics.com
# error occured while parsing gamespot.com
# error occured while parsing zcool.com.cn
# error occured while parsing epfindia.gov.in
# error occured while parsing macys.com
# error occured while parsing notifications.website
# error occured while parsing force.com
# error occured while parsing irctc.co.in
# error occured while parsing nintendo.com
# error occured while parsing investing.com
# error occured while parsing exhentai.org
# error occured while parsing tencent.com
# error occured while parsing uptobox.com
# error occured while parsing ptt.cc
# error occured while parsing rpgmasterleague.com
# error occured while parsing grammarly.com
# error occured while parsing acs.org
# error occured while parsing 178.com
# error occured while parsing w3school.com.cn
# error occured while parsing storiespace.com
# error occured while parsing delta.com
# error occured while parsing eastday.com
# error occured while parsing redfin.com
# error occured while parsing godaddy.com
# error occured while parsing office365.com
# error occured while parsing youdao.com
# error occured while parsing animeflv.net
# error occured while parsing 360.com
# error occured while parsing uidai.gov.in
# error occured while parsing syosetu.com
# error occured while parsing dangdang.com
# error occured while parsing herokuapp.com
# error occured while parsing naukri.com
# error occured while parsing cnzz.com
# error occured while parsing yahoo.co.jp
# error occured while parsing sciencedirect.com
# error occured while parsing mobile01.com
# error occured while parsing caixa.gov.br
# error occured while parsing afreecatv.com
# error occured while parsing sina.com.cn
# error occured while parsing binance.com
# error occured while parsing wikimedia.org
# error occured while parsing wattpad.com
# error occured while parsing abola.pt
# error occured while parsing prnt.sc
# error occured while parsing live.com
# error occured while parsing gmarket.co.kr
# error occured while parsing notify-service.com
# error occured while parsing rednet.cn
# error occured while parsing line.me
# error occured while parsing gamersky.com
# error occured while parsing mercari.com
# error occured while parsing azure.com
# error occured while parsing heroesofrpg.com
# error occured while parsing zhaopin.com
# error occured while parsing yespornplease.com
# error occured while parsing akoam.net
# error occured while parsing zhibo8.cc
# error occured while parsing intoday.in
# error occured while parsing jb51.net
# error occured while parsing naver.jp
# error occured while parsing bestbuy.com
# error occured while parsing blog.me
# error occured while parsing getawesome1.com
# error occured while parsing bankmellat.ir
# error occured while parsing crptgate.com
# error occured while parsing panda.tv
# error occured while parsing dspmulti.com
# error occured while parsing myshopify.com
# error occured while parsing hatenablog.com
# error occured while parsing fc2.com
# error occured while parsing japanpost.jp
# error occured while parsing patria.org.ve
# error occured while parsing joins.com
# error occured while parsing jooble.org
# error occured while parsing poe.trade
# error occured while parsing asos.com
# error occured while parsing canada.ca
# error occured while parsing brilio.net
# error occured while parsing drudgereport.com
# error occured while parsing aliyun.com
# error occured while parsing myanmarload.com
# error occured while parsing book118.com
# error occured while parsing wikipedia.org
# error occured while parsing pchome.com.tw
# error occured while parsing mayoclinic.org
# error occured while parsing caijing.com.cn
# error occured while parsing hh.ru
# error occured while parsing siteadvisor.com
# error occured while parsing accuweather.com
# error occured while parsing hp.com
# error occured while parsing office.com

# %%
print(pd.DataFrame(user_agents, columns=['User Agents (Distinct)']).to_string())
# Out:
#                                 User Agents (Distinct)
# 0                                           WebZIP/5.0
# 1                                     The Intraformant
# 2                                               Daumoa
# 3                   ADmantX Platform Semantic Analyzer
# 4                                           CompSpyBot
# 5                                     Wandoujia Spider
# 6                                         zoomRank/2.0
# 7                                          NetMechanic
# 8                                              wegobot
# 9                                              Balihoo
# 10                                  magpie-crawler/1.1
# 11                                   Search360-Crawler
# 12                                AdsBot-Google-Mobile
# 13                                            Copernic
# 14                                       YandexMetrika
# 15                                             BLEXBot
# 16                                             mozDex*
# 17                        Clickagy Intelligence Bot v2
# 18                                               KaBot
# 19                                              Solbot
# 20                                          MIIxpc/4.2
# 21                                         OmtrBot/1.0
# 22                                           auramundi
# 23                                              proxem
# 24                                    alexa site audit
# 25                      test-url/1.0 libwww-perl/5.800
# 26                                             Gigabot
# 27     Rome Client (http://tinyurl.com/64t5n) Ver: 0.9
# 28                                        ExtractorPro
# 29                                    ProPowerBot/2.14
# 30                                    IntuitGSACrawler
# 31                                           AhrefsBot
# 32                                          fr_crawler
# 33                                       BaiduMobaider
# 34                                            Applebot
# 35                                          Mister PiX
# 36                                         MSIECrawler
# 37                                              msrbot
# 38                                  NetResearchServer*
# 39                                    Baiduspider-cpro
# 40                                            SpankBot
# 41                                          MSNPTC/1.0
# 42                                        YandexImages
# 43                                     Googlebot-Video
# 44                                         yisouspider
# 45                                   Baiduspider-image
# 46                                        Iron33/1.0.2
# 47                          sitecheck.internetseer.com
# 48                                           WebReaper
# 49                      test-url/1.0 libwww-perl/5.801
# 50                                            Moreover
# 51                                     SimplePie/1.1.3
# 52                                              omgili
# 53                                                 puf
# 54                                             Zealbot
# 55                                     ArchitextSpider
# 56                                       berlin-fu-cow
# 57                                        URLy Warning
# 58                                      Download Ninja
# 59                                         SiteSnagger
# 60                                Mediapartners-Google
# 61                                               teoma
# 62                                            ScoutJet
# 63                                     gsa-crawler-www
# 64                                               CCBot
# 65                                                 Zao
# 66   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT;...
# 67                                              Yandex
# 68                                            scoop.it
# 69                                            heritrix
# 70                                              DotBot
# 71                                             b2w/0.1
# 72                   Zeus 32297 Webster Pro V2.9 Win32
# 73                             Radiation Retriever 1.1
# 74                                       YoudaoBot/1.0
# 75                                       FairAd Client
# 76                                          SlySearch*
# 77                         ia_archiver-web.archive.org
# 78                                   red-app-gsa-p-one
# 79                  FAST Enterprise Crawler 6 / Scirus
# 80                                         WebStripper
# 81                                           seznambot
# 82                                             5emeRue
# 83                                               Psbot
# 84                                              Ezooms
# 85                                             Maxthon
# 86   Baiduspider-image+(+http://www.baidu.com/searc...
# 87                                            NaverBot
# 88                                         CazoodleBot
# 89                                          Orthogaffe
# 90                                            Cliqzbot
# 91                                               Sogou
# 92                                          vebidoobot
# 93                                             spanner
# 94                                            k2spider
# 95                                               NPBot
# 96   +Baiduspider/2.0;++http://www.baidu.com/search...
# 97                                                 DOC
# 98                                              Botify
# 99                                     MaxPointCrawler
# 100                                             Augure
# 101                                             cosmos
# 102                                          YandexBot
# 103                                             WebVac
# 104                                       +Baiduspider
# 105                                         Riddlerbot
# 106                                MS Search 4.0 Robot
# 107                                           naverbot
# 108                                        archive.org
# 109                                          CNCDialer
# 110                                            moatbot
# 111                                        TelegramBot
# 112                                            SiteArc
# 113                                MS Search 6.0 Robot
# 114                              aibangbot Disallow: /
# 115                                         HMSE_Robot
# 116                                            Freedom
# 117                                        DuckDuckBot
# 118                                          googlebot
# 119                         cisco-googlebot-enterprise
# 120                                             Cision
# 121                                           test-url
# 122                                        Sogouspider
# 123                              KDDI-Googlebot-Mobile
# 124                                    YaDirectFetcher
# 125                                            yacybot
# 126                                            suzuran
# 127                             Openfind data gatherer
# 128                                       TurnitinBot*
# 129                                           Digimind
# 130                                          WebCopier
# 131                                          Charlotte
# 132                                              FAST*
# 133                                             Pu_iN*
# 134                                          Mata Hari
# 135  Mozilla/5.0 (compatible; Taboolabot/3.7; +http...
# 136                                       Yahoo! Slurp
# 137                                           Netvibes
# 138                                   googlebot-mobile
# 139                                    opinion-tracker
# 140                                      InfoNaviRobot
# 141                                           Teleport
# 142                            google-hoteladsverifier
# 143                                             bender
# 144                                            Newzbin
# 145                                    Googlebot-Image
# 146                                         Ezooms/1.0
# 147                                      BunnySlippers
# 148                                             uipbot
# 149                                         Ask n read
# 150                                                  *
# 151                     test-url/1.0 libwww-perl/5.803
# 152                               netEstate NE Crawler
# 153           Mozilla/5.0 (compatible; Google-Podcast)
# 154                                           Wget/1.6
# 155                                       msnbot-media
# 156                             WebmasterWorldForumBot
# 157                             YandexAccessibilityBot
# 158                                         Powermarks
# 159                                    Yahoo Pipes 1.0
# 160                                   YandexSearchShop
# 161                                             google
# 162                                               FAST
# 163                             CrazyWebCrawler-Spider
# 164                              Openfind data gathere
# 165                                    ChangeDetection
# 166                                          OrangeBot
# 167                                             endeca
# 168                                            voltron
# 169                                           IDentity
# 170                                           Telesoft
# 171                                       HaosouSpider
# 172                                          psnsearch
# 173                                             ZyBORG
# 174                                         SandDollar
# 175                                          grapeshot
# 176                                        LinkedInBot
# 177                                   +Baiduspider/2.0
# 178                                          SocSciBot
# 179                                             wotbox
# 180                                     FunWebProducts
# 181                                               Pipl
# 182                                        TeleportPro
# 183                                         EtaoSpider
# 184                     Jakarta Commons-HttpClient/3.1
# 185                                     Twitterbot/1.0
# 186                                        Rome Client
# 187                                              psbot
# 188                          AdsBot-Google-Mobile-Apps
# 189                                        AmiSoftware
# 190                                      MnoGoSearch/*
# 191                             aibang.com Disallow: /
# 192                                      NimbleCrawler
# 193                                      Snarfer/1.0.2
# 194                                    Baiduspider-ads
# 195                                 Libreprensabot/1.0
# 196                                          Owlin Bot
# 197                                           JennyBot
# 198                                     URL_Spider_Pro
# 199                                        GermCrawler
# 200                                             Xagool
# 201                                           CatchBot
# 202                                              moget
# 203                                        WebEnhancer
# 204                                          Googlebot
# 205                                           Crescent
# 206                                  Sogou inst spider
# 207                                    YandexWebmaster
# 208                                  YandexVideoParser
# 209                                        duckduckbot
# 210                                Keyword Density/0.9
# 211                                     Googlebot-News
# 212                              toCrawl/UrlDispatcher
# 213                                        baiduspider
# 214                                           TheNomad
# 215                                      Sogou spider2
# 216                                         True_Robot
# 217                                      AdsBot-Google
# 218                  Microsoft URL Control - 5.01.4511
# 219                                    WebCopier v3.2a
# 220                                        lwp-trivial
# 221                                            Openbot
# 222                                          KSCrawler
# 223                                      ChinasoSpider
# 224                             Fast corporate crawler
# 225                                            Gaisbot
# 226                                            LexiBot
# 227                                     WebCapture 2.0
# 228                                    YandexDirectDyn
# 229                                        ia_archiver
# 230                          trendkite-akashic-crawler
# 231                                           Openfind
# 232                                            netseer
# 233                                          Flipboard
# 234                                             coccoc
# 235                                         LinkWalker
# 236                                    ia_archiver/1.6
# 237                          Screaming Frog SEO Spider
# 238                                          360spider
# 239    Flipboard/3.2.6 CFNetwork/711.0.6 Darwin/14.0.0
# 240                                              Fetch
# 241                            Xenu's Link Sleuth 1.1c
# 242                                         trendybuzz
# 243                                              Nutch
# 244                                        URL Control
# 245                                          MegaIndex
# 246                                   YandexMedianaBot
# 247                                   SearchmetricsBot
# 248                                            leadbox
# 249                                             PerMan
# 250                                        EasouSpider
# 251                                           Knowings
# 252                                            winello
# 253                                    archive.org_bot
# 254                              Clickagy Intelligence
# 255                                        Aboundexbot
# 256                     RepoMonkey Bait & Tackle/v1.01
# 257                                          Talkwater
# 258                                         EdisterBot
# 259                                          careerbot
# 260                                            Speobot
# 261                                       YandexDirect
# 262                                            Uniscan
# 263                                           AdIdxBot
# 264                                      msnbot-mobile
# 265                                              Teoma
# 266                                            spotter
# 267                                            MauiBot
# 268                                       StackRambler
# 269                                               Gort
# 270                                        gsa-crawler
# 271                           WebmasterWorld Extractor
# 272                                    Website Quester
# 273                                               Wget
# 274                                           twiceler
# 275                                   blinkx_ff_spider
# 276                                   lwp-trivial/1.34
# 277                                      omgilibot/0.3
# 278                                          flipboard
# 279                                           Scooter*
# 280                 Acunetix Web Vulnerability Scanner
# 281                                   CRAZYWEBCRAWLER*
# 282                                     magpie-crawler
# 283                                      searchpreview
# 284                                          Atomz/1.0
# 285                                    Baiduspider/2.0
# 286   Crescent Internet ToolPak HTTP OLE Control v.1.0
# 287                                        grub-client
# 288                                            NetAnts
# 289                                      Yahoo!  Slurp
# 290                                         SputnikBot
# 291                                          GoogleBot
# 292                                         tadcrawler
# 293                                        Yisouspider
# 294                                         humanlinks
# 295                                              Open*
# 296                                              Wget*
# 297                                             score3
# 298                             Xenu Link Sleuth/1.3.8
# 299  Mozilla/4.0 (compatible; MSIE 4.01; Windows NT...
# 300                                          deepcrawl
# 301                                          WeSEE_Bot
# 302                                            BotALot
# 303                                    JobdiggerSpider
# 304                                    TerrawizBot/1.0
# 305                                            sistrix
# 306                                          GurujiBot
# 307                                             coexel
# 308                                        WBSearchBot
# 309                                      ToutiaoSpider
# 310                                    YandexSitelinks
# 311                                             exabot
# 312  Baiduspider+(+http://www.baidu.com/search/spid...
# 313                        www.integromedb.org/Crawler
# 314                                          moget/2.1
# 315                                         UbiCrawler
# 316                                           Alexibot
# 317                                              nutch
# 318            CCBot/2.0 (http://commoncrawl.org/faq/)
# 319                                            NewsNow
# 320                                             vobsub
# 321                              YahooSeeker/M1A1-R2D2
# 322                                         Sogou blog
# 323                                       Laserlikebot
# 324                                           BLP_bbot
# 325                                             dotbot
# 326                                              5erue
# 327                                             WebZip
# 328                                             larbin
# 329                                   Baiduspider-news
# 330                                 aibang Disallow: /
# 331                                                nsa
# 332                                           WebSnake
# 333                                      SemrushBot-SA
# 334                                          YoudaoBot
# 335                            Google-HotelAdsVerifier
# 336                                    WWW-Collector-E
# 337                                            Spinn3r
# 338                                               yeti
# 339                                             Kraken
# 340                                       TightTwatBot
# 341                                           Alexabot
# 342                                         JikeSpider
# 343                                        EmailSiphon
# 344                                            Bingbot
# 345                                           test url
# 346                                    adequat-systems
# 347                                            gigabot
# 348                                     FlipboardProxy
# 349                              Mediapartners-Google*
# 350                                          CheeseBot
# 351                                      ContextAd Bot
# 352                                            HTTrack
# 353                                          DeepCrawl
# 354                                         SemrushBot
# 355                                        NPBot-1/2.0
# 356                                             BUbiNG
# 357                                       BLP_bbot/0.1
# 358                                     EmailCollector
# 359                                        Snapbot/1.0
# 360                               Sogou web spider/3.0
# 361                                         OnetSzukaj
# 362                                        Szukacz/1.4
# 363                                Web Image Collector
# 364                                         Wget/1.5.3
# 365                                  QueryN Metasearch
# 366                             koubei.com Disallow: /
# 367                                             bhcBot
# 368                                        TurnitinBot
# 369                                              spbot
# 370  Mozilla/4.0 (compatible; Netcraft Web Server S...
# 371                                     googlebot_news
# 372                                        LinkChecker
# 373   SQUID_configured_as_described_at_/help/faq/cache
# 374                                            DotBot*
# 375                                         Superfeedr
# 376                                        HTTrack 3.0
# 377                                     Go-http-client
# 378                                           rogerbot
# 379                                externalfacebookhit
# 380                                        LNSpiderguy
# 381                                    TurnitinBot/1.5
# 382                                            mention
# 383                                YandexScreenshotBot
# 384                                          trovitBot
# 385                                             WikiDo
# 386                                    WebAlta Crawler
# 387                                           asterias
# 388                                            Mail.Ru
# 389                                    WebCopier v.2.2
# 390                                      Aqua_Products
# 391                                       GwdangSpider
# 392                                         RepoMonkey
# 393                                             WebZIP
# 394                                            trendeo
# 395                                             Bender
# 396                                        YandexVideo
# 397                                       Java Browser
# 398                                        linkfluence
# 399                                          WebBandit
# 400                              CherryPickerElite/1.0
# 401                                      ichiro/mobile
# 402                                         Exabot/3.0
# 403                                             Jetbot
# 404                                         EroCrawler
# 405                                          360Spider
# 406                                          looksmart
# 407                                            Facebot
# 408                                         Bitvorebot
# 409                                               Zite
# 410                                   OmniExplorer_Bot
# 411                                    YandexMobileBot
# 412                                             Foobot
# 413                                           Tailrank
# 414                                          NICErsPRO
# 415                                          Clickagy*
# 416                                    yahoo-mmcrawler
# 417                                             Lizard
# 418                                               Zeus
# 419                              Microsoft URL Control
# 420                                        linguatools
# 421                                               grub
# 422                                         Telefonica
# 423                                       HaoSouSpider
# 424                                       Baiduspider+
# 425  Mozilla/4.0 (compatible; MSIE 4.01; Windows NT...
# 426                                             Krugle
# 427                  Microsoft URL Control - 6.00.8169
# 428                             aibang-bot Disallow: /
# 429                                              Link*
# 430                                  ichiro/mobile goo
# 431                                       ProWebWalker
# 432                                       BotRightHere
# 433                                            Pingdom
# 434                                        vecteurplus
# 435                                        YisouSpider
# 436                                    Zeus Link Scout
# 437                                        Mail.RU_Bot
# 438                                          BecomeBot
# 439                          aibang-spider Disallow: /
# 440                                           Meltawer
# 441                                     Callpod Keeper
# 442                                             Speedy
# 443                         www.aibang.com Disallow: /
# 444                                           smspider
# 445                                            MJ12bot
# 446                                            adequat
# 447                                        BingPreview
# 448                                    BackDoorBot/1.0
# 449                                    Google-Sitemaps
# 450  Mozilla/5.0 (compatible; Sosospider/2.0; +http...
# 451                             Domain Re-Animator Bot
# 452                                                VCI
# 453  Sogou Pic Spider/3.0(+http://www.sogou.com/doc...
# 454  Mozilla/5.0 (compatible; heritrix/3.2.0 +http:...
# 455                                           Relcybot
# 456                                      PortalBSpider
# 457  Mozilla/5.0 (compatible; bnf.fr_bot; +http://w...
# 458                                               Xenu
# 459     Mozilla/4.0 (compatible; BullsEye; Windows 95)
# 460                                      BuiltBotTough
# 461                                           discobot
# 462                                facebookexternalhit
# 463                                            STC-bot
# 464                                        Y!J-MBS/1.0
# 465                                          CCBot/2.0
# 466                                             msnbot
# 467                                     googlebot-news
# 468                                   BaiduImagespider
# 469                                          Uptimebot
# 470                                       BlowFish/1.0
# 471                                        WebZIP/4.21
# 472                                         Genieo/1.0
# 473                                     verticalsearch
# 474                                          MagpieRSS
# 475                           koubeispider Disallow: /
# 476                                OrangeBot-Collector
# 477                                            sitebot
# 478                                    YandexOntoDBAPI
# 479                                             Xenu's
# 480                                   ParadigmCrawler*
# 481  Mozilla/4.0 (compatible; MSIE 6.0; Windows NT;...
# 482  Baiduspider/2.0;+http://www.baidu.com/search/s...
# 483                                         Sosospider
# 484                                            hloader
# 485                                         dotbot/1.0
# 486                                         NetinfoBot
# 487                                               wget
# 488                                            Scrubby
# 489                                          psbot/0.1
# 490                                         BlogSearch
# 491                                 CherryPickerSE/1.0
# 492                                         AhrefsBots
# 493                                          omgilibot
# 494                                innosense/Nutch-1.0
# 495                                                008
# 496                  VCI WebViewer VCI WebViewer Win32
# 497                                             SWEBot
# 498                               Bookmark search tool
# 499                                CrystalSemanticsBot
# 500                               Sogou web spider/4.0
# 501                           aibangspider Disallow: /
# 502                                          Corporama
# 503                                  Baiduspider-video
# 504                                       Pinterestbot
# 505                                   LinkextractorPro
# 506                                       CherryPicker
# 507                                       asknread.com
# 508                                    Yahoo-MMCrawler
# 509                                             daumoa
# 510                                         Sitereport
# 511                                           Swiftbot
# 512                                                vsw
# 513                                            Rambler
# 514                                    Googlebot-image
# 515                                             Feedly
# 516                                           VoilaBot
# 517                                            PiplBot
# 518                                   Baiduspider-favo
# 519                                           Seekbot*
# 520                                             MIIxpc
# 521                                       GetRight/4.2
# 522                                          Meltwater
# 523                                          Pinterest
# 524                                         WebZip/4.0
# 525                                   NextGenSearchBot
# 526                                          WebSauger
# 527                                     ConveraCrawler
# 528                                           Naverbot
# 529                                            ZyBorg*
# 530                                     libWeb/clsHTTP
# 531                                   Googlebot-Mobile
# 532                                        FBSearchBot
# 533                                      cis455crawler
# 534                                           turingos
# 535                                        Webster Pro
# 536                                           Niki-Bot
# 537                                           adidxbot
# 538                                          SeznamBot
# 539                                        Baiduspider
# 540                                            WebAlta
# 541                                     trendictionbot
# 542                                       Bullseye/1.0
# 543                                   Offline Explorer
# 544                                       Teleport Pro
# 545                                            ADmantX
# 546                                              Slurp
# 547                                     YandexCalendar
# 548                                 Baiduspider-mobile
# 549                                             Youmag
# 550                                          EmailWolf
# 551                                               Yeti
# 552                                         YandexNews
# 553                                        Harvest/1.5
# 554                                 LinkScan/8.1a Unix
# 555                                           ShopWiki
# 556                                          Robozilla
# 557                                           alexabot
# 558                                             Exabot
# 559                                             blinkx
# 560                                             MSNBot
# 561                                           Cincobot
# 562                                           Searchie
# 563                                           Adidxbot
# 564                                           proximic
# 565                                           infoseek
# 566                                            httplib
# 567                                   discoverybot/2.0
# 568                                 Superfeedr bot/2.0
# 569                                   yahoo-blogs/v3.9
# 570                                    googlebot-image
# 571                                            bingbot
# 572                                        Web-By-Mail
# 573                                      Adsbot-Google
# 574                                         DISCo Pump
# 575                                        Y!J-SRD/1.0
# 576            BlogSearch/2 +http://www.icerocket.com/
# 577                                     A6-Indexer/1.0
# 578                                             libwww
# 579                                               BBot
# 580                                      MoodleBot/1.0
# 581                                        YadirectBot
# 582  Mozilla/5.0(compatible; Baiduspider/2.0; +http...
# 583                     omgili/0.5 +https://omgili.com
# 584                                            kbcrawl
# 585                                             Sindup
# 586                                     CopyRightCheck
# 587                                     WebBandit/3.50
# 588                                           Nigma.ru
# 589                                            WebAuto
# 590                                        DittoSpyder
# 591                                  Flaming AttackBot
# 592                                     True_Robot/1.0
# 593                                       Browsershots
# 594                                      Python-urllib
# 595                          Qwam content intelligence
# 596                          Acunetix Security Scanner
# 597                                           Twiceler
# 598                                        DuckDuckbot
# 599                                          Synthesio
# 600                                                RMA
# 601                                         Archive-It
# 602                                         ellisphere
# 603                                             Ocelli
# 604                                       SiteExplorer
# 605                                      Kenjin Spider
# 606                                                 *;
# 607                                              linko
# 608  Mozilla/5.0 (compatible; JikeSpider; +http://s...
# 609                                         Twitterbot
# 610                                  TrustpilotCrawler
# 611                                         WebSearch*
# 612                                                PHP
# 613                                  Sogou News Spider
# 614                                       HuihuiSpider
# 615                                         BrandONbot
# 616                                Oracle Ultra Search
# 617                                       Mail.RU_Bot*
# 618                                            larbin*
# 619                                 Sogou Orion spider
# 620                                   Sogou web spider
# 621                                           NerdyBot
# 622                                           YodaoBot
# 623                                     WochachaSpider
# 624                                             mytwip
# 625                              Microsoft.URL.Control
# 626                                            sosobot
# 627                                              PGBot

# %%
display(pd.DataFrame(directive_count.items(), columns=['Directive', 'Count']))
# Out:
#                                             Directive  Count
# 0                                          user-agent   2917
# 1                                            disallow  56575
# 2                                         crawl-delay     97
# 3                                             sitemap   5210
# 4                                               allow   5426
# 5                                         clean-param     46
# 6                                                host     38
# 7   <!doctype html><html class="en-us no-js  " lan...      1
# 8                                             noindex    502
# 9   <!doctype html public "-//w3c//dtd xhtml 1.0 s...      5
# 10                                  <html xmlns="http      9
# 11                                        ﻿user-agent      6
# 12                                       request-rate      6
# 13                                         visit-time      1
# 14                            <html style="background      1
# 15                                       {"timestamp"      1
# 16                                            <!-- fd      1
# 17  <!doctype html public "-//w3c//dtd xhtml 1.0 t...      4
# 18  <!doctype html><html><head><title>ign error 40...      1
# 19  <!doctype html /><html><head><title data-react...      1
# 20                         new date().gettime(),event      1
# 21  <!doctype html><html><head><title>apache tomca...      1
# 22  <!doctype html><html><head><meta charset="utf-...      1
# 23  <!doctype html><html class="no-js" lang="en" d...      1
# 24                                  @media (min-width      1
# 25  <!doctype html public "-//w3c//dtd html 4.01 t...      1
# 26                                            disllow      1
# 27  <!doctype html public "-//softquad//dtd hotmet...      1
# 28  <!doctype html> <html lang="en"> <head> <meta ...      1
# 29  <!doctype html><html lang="en"><head><meta cha...      1
# 30  var $default_lang="";</script><link rel="style...      1
# 31  <!doctype html public "-//w3c//dtd xhtml 1.0 t...      1
# 32                                 <html xmlns="https      1

# %%
display(pd.DataFrame(map(lambda x: [x[0], x[1], x[1]*100/website_count], count_per_website.items()), columns=['Directive', 'Number of Websites', '%']))
# Out:
#                                             Directive  Number of Websites  \
# 0                                          user-agent                 786
# 1                                            disallow                 749
# 2                                         crawl-delay                  70
# 3                                             sitemap                 436
# 4                                               allow                 348
# 5                                         clean-param                  14
# 6                                                host                  38
# 7   <!doctype html><html class="en-us no-js  " lan...                   1
# 8                                             noindex                  25
# 9   <!doctype html public "-//w3c//dtd xhtml 1.0 s...                   5
# 10                                  <html xmlns="http                   9
# 11                                        ﻿user-agent                   6
# 12                                       request-rate                   4
# 13                                         visit-time                   1
# 14                            <html style="background                   1
# 15                                       {"timestamp"                   1
# 16                                            <!-- fd                   1
# 17  <!doctype html public "-//w3c//dtd xhtml 1.0 t...                   4
# 18  <!doctype html><html><head><title>ign error 40...                   1
# 19  <!doctype html /><html><head><title data-react...                   1
# 20                         new date().gettime(),event                   1
# 21  <!doctype html><html><head><title>apache tomca...                   1
# 22  <!doctype html><html><head><meta charset="utf-...                   1
# 23  <!doctype html><html class="no-js" lang="en" d...                   1
# 24                                  @media (min-width                   1
# 25  <!doctype html public "-//w3c//dtd html 4.01 t...                   1
# 26                                            disllow                   1
# 27  <!doctype html public "-//softquad//dtd hotmet...                   1
# 28  <!doctype html> <html lang="en"> <head> <meta ...                   1
# 29  <!doctype html><html lang="en"><head><meta cha...                   1
# 30  var $default_lang="";</script><link rel="style...                   1
# 31  <!doctype html public "-//w3c//dtd xhtml 1.0 t...                   1
# 32                                 <html xmlns="https                   1
#
#             %
# 0   81.450777
# 1   77.616580
# 2    7.253886
# 3   45.181347
# 4   36.062176
# 5    1.450777
# 6    3.937824
# 7    0.103627
# 8    2.590674
# 9    0.518135
# 10   0.932642
# 11   0.621762
# 12   0.414508
# 13   0.103627
# 14   0.103627
# 15   0.103627
# 16   0.103627
# 17   0.414508
# 18   0.103627
# 19   0.103627
# 20   0.103627
# 21   0.103627
# 22   0.103627
# 23   0.103627
# 24   0.103627
# 25   0.103627
# 26   0.103627
# 27   0.103627
# 28   0.103627
# 29   0.103627
# 30   0.103627
# 31   0.103627
# 32   0.103627
